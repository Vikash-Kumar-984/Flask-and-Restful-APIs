# %%
API_KEY="ab6d708b5b4142cba5f61839b74b9e3b"

# %%
url="https://newsapi.org/v2/everything?q=tesla&from=2025-06-12&sortBy=publishedAt&apiKey=ab6d708b5b4142cba5f61839b74b9e3b"

# %%
import requests

# %%
response = requests.get(url)

# %%
response #<Response [200]> means the request is successful accepted and executed
# Out:
# <Response [200]>

# %%
news_data = response.json()
news_data
# Out:
# {'status': 'ok',
#  'totalResults': 14734,
#  'articles': [{'source': {'id': None, 'name': 'Inside the Magic'},
#    'author': 'Chloe James',
#    'title': 'REPORT: Universal Working With Elon Musk To Connect Its Parks Via Tunnels',
#    'description': 'In one of the wildest reports to emerge about Orlando’s theme park industry in recent memory, it seems like Universal wants to work with Elon Musk to build a series of tunnels to connect its sprawling campus. Universal Orlando Resort offers an immersive theme…',
#    'url': 'https://insidethemagic.net/?p=780974&preview=true&preview_id=780974',
#    'urlToImage': 'https://insidethemagic.net/wp-content/uploads/2025/05/epic-universe-2.jpg',
#    'publishedAt': '2025-07-11T10:56:06Z',
#    'content': 'In one of the wildest reports to emerge about Orlando’s theme park industry in recent memory, it seems like Universal wants to work with Elon Musk to build a series of tunnels to connect its sprawlin… [+4036 chars]'},
#   {'source': {'id': 'der-tagesspiegel', 'name': 'Der Tagesspiegel'},
#    'author': 'Thorsten Metzner',
#    'title': 'Trotz Absatzeinbruch : Tesla drosselt Produktion in Grünheide nicht',
#    'description': 'Elon Musk hat weiter mit Absatzproblemen des Tesla-Konzerns zu kämpfen. Im Werk in Grünheide läuft die Produktion weiter stabil. Doch es gibt erneut Probleme mit dem Wasserlieferanten.',
#    'url': 'https://www.tagesspiegel.de/potsdam/brandenburg/trotz-absatzeinbruch-tesla-drosselt-produktion-in-grunheide-nicht-14002247.html',
#    'urlToImage': 'https://www.tagesspiegel.de/images/11173360/alternates/BASE_16_9_W1400/1752220237000/tesla-gigafactory.jpeg',
#    'publishedAt': '2025-07-11T10:39:11Z',
#    'content': 'Trotz der aktuellen Absatzprobleme drosselt Tesla die Produktion in Grünheide nicht. In der Gigafactory Berlin-Brandenburg laufen aktuell weiterhin circa 5000 Fahrzeuge pro Woche vom Band. Das bestät… [+5532 chars]'},
#   {'source': {'id': 'rte', 'name': 'RTE'},
#    'author': 'Gill Stedman',
#    'title': 'New EV sales jump almost 30% in first half of year',
#    'description': 'Sales of new electric vehicles jumped almost 30% in the first half of the year when compared to the same time last year.',
#    'url': 'https://www.rte.ie/news/business/2025/0711/1523019-new-ev-sales-jump-almost-30-in-first-half-of-year/',
#    'urlToImage': 'https://www.rte.ie/images/001ecb9f-1600.jpg',
#    'publishedAt': '2025-07-11T10:32:55Z',
#    'content': 'Sales of new electric vehicles jumped almost 30% in the first half of the year when compared to the same time last year.\r\nNew figures from the Central Statistics Office show that 13,102 new EVs were … [+1175 chars]'},
#   {'source': {'id': None, 'name': 'COMPUTER BILD'},
#    'author': 'Charlotte Ziesing',
#    'title': 'Grok bald als Sprachassistent bei Tesla',
#    'description': 'Tesla-Fahrzeuge bekommen bald Grok als neuen Sprachassistenten. Doch das KI-Modell sorgte zuletzt für einen Skandal auf der Plattform X.',
#    'url': 'https://www.computerbild.de/artikel/News-Connected-Car-Grok-bald-als-Sprachassistent-bei-Tesla-39846903.html',
#    'urlToImage': 'https://i.computer-bild.de/imgs/1/5/6/7/0/6/9/1/Ein-Bildschirm-neben-dem-Lenkrad-eines-Autos-mit-Grok-Logo--3567-2048x1152-1a9924af4f5f91be.jpg',
#    'publishedAt': '2025-07-11T10:32:00Z',
#    'content': 'Einfach zum neuen Auto\r\nFinde günstige Kauf- und Leasingdeals\r\nDeine Carwow Vorteile:\r\nTransparente Preise\r\nVertrauenswürdige Händler\r\nAngebote aus deiner Nähe\r\nStressfrei &amp; ohne Verhandeln'},
#   {'source': {'id': None, 'name': 'Ritholtz.com'},
#    'author': 'Barry Ritholtz',
#    'title': '10 Friday AM Reads',
#    'description': 'My end-of-week morning train WFH reads: • Why Americans Can’t Buy the World’s Best Electric Car: You’ve probably heard of BYD. A middling player in the auto industry just a few years ago, the Chinese electric vehicle manufacturer BYD surpassed Tesla last year…',
#    'url': 'https://ritholtz.com/2025/07/10-friday-am-reads-458/',
#    'urlToImage': 'https://ritholtz.com/wp-content/uploads/2026/12/inventory.png',
#    'publishedAt': '2025-07-11T10:30:53Z',
#    'content': 'Why Americans Cant Buy the Worlds Best Electric Car: Youve probably heard of BYD. A middling player in the auto industry just a few years ago, the Chinese electric vehicle manufacturer BYD surpassed … [+3231 chars]'},
#   {'source': {'id': None, 'name': 'Forbes'},
#    'author': 'Giacomo Tognini, Forbes Staff, \n Giacomo Tognini, Forbes Staff\n https://www.forbes.com/sites/giacomotognini/',
#    'title': 'Meet The Italian Billionaire Behind Ferrero’s $3.1 Billion Deal For Kellogg',
#    'description': "Since 2015, Giovanni Ferrero has expanded his family's company beyond brands like Nutella and built a global powerhouse—especially through big acquisitions in the U.S.",
#    'url': 'https://www.forbes.com/sites/giacomotognini/2025/07/11/meet-the-italian-billionaire-behind-ferreros-giovanni-ferrero-froot-loops-nutella-31-billion-deal-for-kellogg/',
#    'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/6870343e803c674b0710e14e/0x0.jpg?format=jpg&height=900&width=1600&fit=bounds',
#    'publishedAt': '2025-07-11T10:30:00Z',
#    'content': 'When Italian candy and food giant Ferreroannounced it would acquire WK Kellogg the cereal maker behind Froot Loops and Corn Flakesfor $3.1 billion on Thursday, it wasnt just one of the largest deals … [+9592 chars]'},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Aarian Marshall',
#    'title': '5 Big EV Takeaways From Trump’s ‘One Big Beautiful Bill’',
#    'description': 'The new US legislation isn’t great for electric vehicles. But experts have advice for how the EV-curious buyer might navigate this tricky moment—and there’s even some good news to be found.',
#    'url': 'https://www.wired.com/story/5-big-ev-takeaways-one-big-beautiful-bill/',
#    'urlToImage': 'https://media.wired.com/photos/686ecaf17fa106a22b5bf1b8/191:100/w_1280,c_limit/BBB-EV-Drivers-Gear-2222356286.jpg',
#    'publishedAt': '2025-07-11T10:30:00Z',
#    'content': 'If youre an electric vehicle enthusiast, President Donald Trump and congressional Republicans One Big Beautiful Bill (OBBB) is anything but. The legislation, signed by the president last weekend, cut… [+3910 chars]'},
#   {'source': {'id': None, 'name': "Paul Tan's Automotive News"},
#    'author': 'Anthony Lim',
#    'title': 'Top 20 EV brands in June 2025 – BYD leads, Proton eMas back in 2nd, beating Tesla; Chery, BMW in top 5',
#    'description': 'As it was in May, June saw BYD retain its position as Malaysia’s best selling EV brand, with data from the road transport department (JPJ) revealing 1,045 units from the brand being registered last month. […]\nThe post Top 20 EV brands in June 2025 – BYD leads…',
#    'url': 'https://paultan.org/2025/07/11/top-20-ev-brands-in-june-2025-byd-leads-proton-emas-back-in-2nd-beating-tesla-chery-bmw-in-top-5/',
#    'urlToImage': 'https://paultan.org/image/2024/11/2024_BYD_Sealion_7_Premium_Malaysia-1-1200x801.jpg',
#    'publishedAt': '2025-07-11T10:25:09Z',
#    'content': 'As it was in May, June saw BYD retain its position as Malaysias best selling EV brand, with data from the road transport department (JPJ) revealing 1,045 units from the brand being registered last mo… [+1627 chars]'},
#   {'source': {'id': None, 'name': 'Daily Geek Show'},
#    'author': 'contact@dailygeekshow.com (DGS)',
#    'title': 'Rien ne va plus pour Musk : Tesla dévisse, xAI dérape, et l’effondrement s’accélère',
#    'description': "Elon Musk pris dans la tourmente : de la politique à l'IA, un empire technologique qui menace de s'effondrer\nThe post Rien ne va plus pour Musk : Tesla dévisse, xAI dérape, et l’effondrement s’accélère appeared first on Daily Geek Show.",
#    'url': 'https://dailygeekshow.com/rien-ne-va-plus-pour-musk-tesla-devisse-xai-derape-et-leffondrement-saccelere/',
#    'urlToImage': 'https://dailygeekshow.com/wp-content/uploads/2025/07/elon-musk-chute-hitler.webp',
#    'publishedAt': '2025-07-11T10:23:27Z',
#    'content': 'Elon Musk pris dans la tourmente : de la politique à l’IA, un empire technologique qui menace de s’effondrer\r\nUne image marquante qui invite à réfléchir aux tensions entre innovation, responsabilité … [+4098 chars]'},
#   {'source': {'id': None, 'name': 'Xataka.com'},
#    'author': 'Antonio Vallejo',
#    'title': 'Grok 4 destroza los test y apunta a ser el modelo de IA más avanzado. El problema es que Elon Musk sigue saboteando sus respuestas',
#    'description': 'xAI ha lanzado Grok 4, su nuevo modelo de inteligencia artificial que está arrasando en los tests de rendimiento más exigentes del sector. El modelo supera a las propuestas de OpenAI, Google y Anthropic en múltiples benchmarks. Y es que a falta de conocer la …',
#    'url': 'https://www.xataka.com/robotica-e-ia/grok-4-destroza-test-apunta-a-ser-modelo-ia-avanzado-problema-que-elon-musk-sigue-saboteando-sus-respuestas',
#    'urlToImage': 'https://i.blogs.es/5b6b6e/grok-final/840_560.jpeg',
#    'publishedAt': '2025-07-11T10:22:35Z',
#    'content': 'xAI ha lanzado Grok 4, su nuevo modelo de inteligencia artificial que está arrasando en los tests de rendimiento más exigentes del sector. El modelo supera a las propuestas de OpenAI, Google y Anthro… [+4167 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'businessinsider.com',
#    'title': 'Tesla and Ford are racing to sell more EVs before the Big Beautiful Bill kills the $7,500 tax credit',
#    'description': "The Cybertruck is one of several Tesla models set to lose the $7,500 tax credit.\nKevin Carter/Getty Images\nAutomakers are telling buyers that if they want to go electric, now is the time.\nTrump's Big Beautiful Bill is set to kill the $7,500 tax incentive for …",
#    'url': 'https://biztoc.com/x/b218ed681ad642e9',
#    'urlToImage': 'https://biztoc.com/cdn/b218ed681ad642e9_s.webp',
#    'publishedAt': '2025-07-11T10:16:08Z',
#    'content': "The Cybertruck is one of several Tesla models set to lose the $7,500 tax credit.Kevin Carter/Getty ImagesAutomakers are telling buyers that if they want to go electric, now is the time.Trump's Big Be… [+150 chars]"},
#   {'source': {'id': None, 'name': "Paul Tan's Automotive News"},
#    'author': 'Jonathan James Tan',
#    'title': 'Top 20 brands in June 2025 – Perodua, Proton, Toyota, Honda, Jaecoo top five; 5 China brands make the list',
#    'description': 'The road transport department’s (JPJ) June numbers are out, and positions one to seven are unchanged from May – Perodua (22,328 units, its lowest monthly sales so far this year), Proton (10,638), Toyota (9,946), Honda […]\nThe post Top 20 brands in June 2025 –…',
#    'url': 'https://paultan.org/2025/07/11/top-20-brands-in-june-2025-perodua-proton-toyota-honda-jaecoo-top-five-5-china-brands-make-the-list/',
#    'urlToImage': 'https://paultan.org/image/2020/01/2020_Perodua_Bezza_FL_13AV_Malaysia_Ext-1-1200x609.jpg',
#    'publishedAt': '2025-07-11T10:14:22Z',
#    'content': 'The road transport department’s (JPJ) June numbers are out, and positions one to seven are unchanged from May – Perodua (22,328 units, its lowest monthly sales so far this year), Proton (10,638), Toy… [+1723 chars]'},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'feedfeeder',
#    'title': 'OpenAI’s next big launch could be an AI web browser - The Verge',
#    'description': 'OpenAI’s next big launch could be an AI web browserThe Verge Exclusive: OpenAI to release web browser in challenge to Google ChromeReuters Is A.I. the Future of Web Browsing?The New York Times Perplexity launches Comet, an AI-powered web browserTechCrunch Tec…',
#    'url': 'https://slashdot.org/firehose.pl?op=view&amp;id=178337090',
#    'urlToImage': None,
#    'publishedAt': '2025-07-11T10:12:26Z',
#    'content': 'The Fine Print: The following comments are owned by whoever posted them. We are not responsible for them in any way.'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'cnbc.com',
#    'title': 'Intel spins out AI robotics company RealSense with $50 million raise',
#    'description': 'Tech companies like Tesla and Amazon have bet big on robotics technology and automation.',
#    'url': 'https://biztoc.com/x/665bd1772a327ae4',
#    'urlToImage': 'https://biztoc.com/cdn/950/og.png',
#    'publishedAt': '2025-07-11T10:04:38Z',
#    'content': 'Tech companies like Tesla and Amazon have bet big on robotics technology and automation.\r\nThis story appeared on cnbc.com, 2025-07-11 10:00:01.'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Tom Carter',
#    'title': 'Tesla and Ford are racing to sell more EVs before the Big Beautiful Bill kills the $7,500 tax credit',
#    'description': "Tesla's website currently displays a banner warning customers that the EV tax credit will come to an end in September.",
#    'url': 'https://www.businessinsider.com/tesla-ford-push-sell-more-evs-before-tax-credit-ends-2025-7',
#    'urlToImage': 'https://i.insider.com/686fd69585e81483682dc0c8?width=1200&format=jpeg',
#    'publishedAt': '2025-07-11T10:03:50Z',
#    'content': 'The Cybertruck is one of several Tesla models set to lose the $7,500 tax credit.Kevin Carter/Getty Images\r\n<ul><li>Automakers are telling buyers that if they want to go electric, now is the time.</li… [+2764 chars]'},
#   {'source': {'id': None, 'name': "Paul Tan's Automotive News"},
#    'author': 'Gerard Lye',
#    'title': 'Top 20 EV models in June 2025 – Proton eMas 7 back on top, BYD Atto 3 and Tesla Model Y in top three',
#    'description': 'After stumbling to second place in May 2025, the Proton eMas 7 is now back on top by being the best-selling electric vehicle (EV) in Malaysia in June 2025. According to the latest data from […]\nThe post Top 20 EV models in June 2025 – Proton eMas 7 back on to…',
#    'url': 'https://paultan.org/2025/07/11/top-20-ev-models-in-june-2025/',
#    'urlToImage': 'https://paultan.org/image/2025/02/2025-Proton-eMas-7-Premium_Ext-4-1200x800.jpg',
#    'publishedAt': '2025-07-11T10:02:05Z',
#    'content': 'After dropping down to second place in May 2025, the Proton eMas 7 is now back on top by being the best-selling electric vehicle (EV) in Malaysia in June 2025. According to the latest data from the r… [+2083 chars]'},
#   {'source': {'id': None, 'name': 'Latercera.com'},
#    'author': 'Antonio Alburquerque',
#    'title': 'Por qué Tesla está en problemas más graves de lo que se creía',
#    'description': 'Mientras Elon Musk intensifica su agenda política, analistas advierten que Tesla enfrenta una caída en ventas, pérdida de beneficios clave y dudas entre los inversores.',
#    'url': 'https://www.latercera.com/tendencias/noticia/por-que-tesla-esta-en-problemas-mas-graves-de-lo-que-se-creia/',
#    'urlToImage': 'https://www.latercera.com/resizer/v2/FBJJDVFM63UZIRXPBHJVJPS4KQ.jpg?auth=a9263aa3eb7a07736027ab934d2cf804cc50be1e6ad50cf9b2be2d32a19ef17f&height=630&width=1200&smart=true',
#    'publishedAt': '2025-07-11T10:01:00Z',
#    'content': 'Las turbulencias en torno a Tesla van mucho más allá de las recientes peleas en redes sociales entre Elon Musk y el presidente de EEUU, Donald Trump.\r\nAunque el cruce de dardos entre ambos magnates h… [+3618 chars]'},
#   {'source': {'id': None, 'name': 'CNBC'},
#    'author': None,
#    'title': 'Intel spins out AI robotics company RealSense with $50 million raise',
#    'description': 'Tech companies like Tesla and Amazon have bet big on robotics technology and automation.',
#    'url': 'https://www.cnbc.com/2025/07/11/intel-ai-robotics-realsense.html',
#    'urlToImage': 'https://image.cnbcfm.com/api/v1/image/103407082-GettyImages-461113104.jpg?v=1752176102&w=1920&h=1080',
#    'publishedAt': '2025-07-11T10:00:01Z',
#    'content': 'Intel is spinning out its artificial intelligence robotics and biometric venture as more companies bet big on automation tools.\r\nThe new company, known as RealSense, was announced Friday and comes al… [+2043 chars]'},
#   {'source': {'id': None, 'name': 'Purepc.pl'},
#    'author': 'Maciej Lewczuk',
#    'title': 'Grok 4 debiutuje w ceniu skandalu. Czy nowy model xAI naprawdę przewyższa ChatGPT i Gemini w każdej dziedzinie?',
#    'description': 'Grok 4 to najnowsza wersja chatbota rozwijanego przez firmę Elona Muska xAI. Premiera zbiegła się w czasie z kontrowersjami wokół wcześniejszej wersji, która publikowała niedopuszczalne treści. Nowy model ma być znacznie bardziej zaawansowany, oferując rozbud…',
#    'url': 'https://www.purepc.pl/grok-4-debiutuje-w-ceniu-skandalu-czy-nowy-model-xai-naprawde-przewyzsza-chatgpt-i-gemini-w-kazdej-dziedzinie',
#    'urlToImage': 'https://www.purepc.pl/image/news/2025/07/11_grok_4_debiutuje_w_ceniu_skandalu_czy_nowy_model_xai_naprawde_przewyzsza_chatgpt_i_gemini_w_kazdej_dziedzinie_0.jpg',
#    'publishedAt': '2025-07-11T10:00:01Z',
#    'content': 'Grok 4 to najnowsza wersja chatbota rozwijanego przez firm Elona Muska xAI. Premiera zbiega si w czasie z kontrowersjami wokó wczeniejszej wersji, która publikowaa niedopuszczalne treci. Nowy model m… [+2336 chars]'},
#   {'source': {'id': None, 'name': 'The New Yorker'},
#    'author': 'Jon Allsop',
#    'title': 'Is Elon Musk’s “America Party” Worth Taking Seriously?',
#    'description': 'Elon Musk’s latest venture into U.S. politics points to cracks in the two-party system—even if it might flop, Jon Allsop writes.',
#    'url': 'https://www.newyorker.com/news/fault-lines/is-elon-musks-america-party-worth-taking-seriously',
#    'urlToImage': 'https://media.newyorker.com/photos/6870254edd2cc138cdcb3b58/16:9/w_1280,c_limit/TNY_FaultLines_250711_ElonParty_Final_01_bleed.jpg',
#    'publishedAt': '2025-07-11T10:00:00Z',
#    'content': 'For this weeks Fault Lines column, Jon Allsop is filling in for Jay Caspian Kang.\r\nThere have been several political groupings called the American Party, or something similar, in U.S. history. Perhap… [+12175 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'barrons.com',
#    'title': 'These Stocks Are Moving the Most Today: Nvidia, MicroStrategy, Boeing, Tesla, Levi Strauss, and More',
#    'description': '',
#    'url': 'https://biztoc.com/x/d3b44e82b3abc2c9',
#    'urlToImage': 'https://biztoc.com/cdn/d3b44e82b3abc2c9_s.webp',
#    'publishedAt': '2025-07-11T09:53:20Z',
#    'content': '{ window.open(this.href, \'_blank\'); }, 200); return false;"&gt;Why is Trump imposing 35% tariffs on Canadian goods? { window.open(this.href, \'_blank\'); }, 200); return false;"&gt;How did Nvidia reach… [+737 chars]'},
#   {'source': {'id': 'focus', 'name': 'Focus'},
#    'author': 'Wolfgang Gomoll',
#    'title': 'Auch Grünheide-Werk betroffen - so tief ist die Tesla-Krise wirklich',
#    'description': 'Elon Musk will hoch hinaus: als Politiker und mit seiner Weltraumfirma SpaceX. Doch Tesla hat ganz irdische Probleme, nämlich einen massiven Absatzrückgang. Das hat auch Folgen für das Werk in Deutschland.',
#    'url': 'https://www.focus.de/auto/news/auch-gruenheide-werk-betroffen-so-tief-ist-die-tesla-krise-wirklich_bed503f8-17b2-44bc-87ca-24aaf068f9ab.html',
#    'urlToImage': 'https://quadro.burda-forward.de/ctf/138ca156-7090-4832-973b-9ab94c7dc529.34552a97-136a-456d-9940-48d8510e05d1.jpg?im=RegionOfInterestCrop%3D%281200%2C630%29%2CregionOfInterest%3D%28721%2C405%29&hash=e68041132b72c43e6d98f25cdb49461f66429922962300e1a8e1d3d7d2041952',
#    'publishedAt': '2025-07-11T09:48:59Z',
#    'content': 'Wenn aus einer Männerfreundschaft eine Feindschaft wird, dann ist dieser Umstand nie besonders angenehm. Handelt es sich bei den beiden zudem um Alpha-Tiere, wird die Schlammschlacht besonders heftig… [+8592 chars]'},
#   {'source': {'id': 'focus', 'name': 'Focus'},
#    'author': 'Wolfgang Gomoll',
#    'title': 'Tesla-Krise: Auch Werk in Grünheide betroffen',
#    'description': 'Elon Musk will hoch hinaus: als Politiker und mit seiner Weltraumfirma SpaceX. Doch Tesla hat ganz irdische Probleme, nämlich einen massiven Absatzrückgang. Das hat auch Folgen für das Werk in Deutschland.',
#    'url': 'https://www.focus.de/auto/news/tesla-krise-auch-werk-in-gruenheide-betroffen_bed503f8-17b2-44bc-87ca-24aaf068f9ab.html',
#    'urlToImage': 'https://quadro.burda-forward.de/ctf/138ca156-7090-4832-973b-9ab94c7dc529.34552a97-136a-456d-9940-48d8510e05d1.jpg?im=RegionOfInterestCrop%3D%281200%2C630%29%2CregionOfInterest%3D%28721%2C405%29&hash=e68041132b72c43e6d98f25cdb49461f66429922962300e1a8e1d3d7d2041952',
#    'publishedAt': '2025-07-11T09:48:59Z',
#    'content': 'Wenn aus einer Männerfreundschaft eine Feindschaft wird, dann ist dieser Umstand nie besonders angenehm. Handelt es sich bei den beiden zudem um Alpha-Tiere, wird die Schlammschlacht besonders heftig… [+8592 chars]'},
#   {'source': {'id': None, 'name': 'Golem.de'},
#    'author': None,
#    'title': 'Nach Austin: Tesla will Robotaxis nach Arizona und Kalifornien bringen',
#    'description': 'Nachdem Tesla in Austin einen ersten eingeschränkten Robotaxi-Dienst gestartet hat, will Elon Musk in weitere Städte expandieren. (Tesla, Elektroauto)',
#    'url': 'https://www.golem.de/sonstiges/zustimmung/auswahl.html?from=https%3A%2F%2Fwww.golem.de%2Fnews%2Fnach-austin-tesla-will-robotaxis-nach-arizona-und-kalifornien-bringen-2507-198003.html&referer=https%3A%2F%2Ft.co%2F3052eb654a',
#    'urlToImage': None,
#    'publishedAt': '2025-07-11T09:47:01Z',
#    'content': 'Besuchen Sie Golem.de wie gewohnt mit Werbung und Tracking,\r\n indem Sie der Nutzung aller Cookies zustimmen.\r\n Details zum Tracking finden Sie im Privacy Center.\r\nSkript wurde nicht geladen. Informat… [+607 chars]'},
#   {'source': {'id': None, 'name': 'DIE WELT'},
#    'author': 'Fabian Hoberg',
#    'title': 'Von null auf 100 km/h in 1,89 Sekunden',
#    'description': 'Der Lucid Air Sapphire beschleunigt nicht nur schneller als ein Formel-1-Bollide, er erzeugt auch ein Fahrgefühl, wie man es bei einem Elektroauto selten erlebt. Hinter dem Unternehmen steckt ein ehemaliger Tesla-Ingenieur.',
#    'url': 'https://www.welt.de/iconist/trends/article256376328/Lucid-Air-Sapphire-gegen-Tesla-Porsche-Der-neue-Koenig-der-Elektro-Limousinen.html',
#    'urlToImage': 'https://images.welt.de/686cccdb22966104c8e3a4c4/b5f3d1aa7252813c5b8e3b47f2e38bce/ci16x9-w1200/lucid-air-sapphire',
#    'publishedAt': '2025-07-11T09:42:20Z',
#    'content': 'Auf den ersten Blick wirkt er harmlos. Doch der Eindruck täuscht. Der Lucid Air Sapphire beschleunigt schneller als ein Formel-1-Bolide und vermittelt ein Fahrgefühl, wie man es bei einem Elektroauto… [+5281 chars]'},
#   {'source': {'id': None, 'name': 'DIE WELT'},
#    'author': 'Fabian Hoberg',
#    'title': 'Von null auf 100 km/h in 1,89 Sekunden',
#    'description': 'Der Lucid Air Sapphire beschleunigt nicht nur schneller als ein Formel-1-Bollide, er erzeugt auch ein Fahrgefühl, wie man es bei einem Elektroauto selten erlebt. Hinter dem Unternehmen steckt ein ehemaliger Tesla-Ingenieur.',
#    'url': 'https://www.welt.de/iconist/trends/plus256376328/Lucid-Air-Sapphire-gegen-Tesla-Porsche-Der-neue-Koenig-der-Elektro-Limousinen.html',
#    'urlToImage': 'https://images.welt.de/686cccdb22966104c8e3a4c4/b5f3d1aa7252813c5b8e3b47f2e38bce/ci16x9-w1200-fnov-fpotl-fpi157750653/lucid-air-sapphire',
#    'publishedAt': '2025-07-11T09:42:20Z',
#    'content': 'Auf den ersten Blick wirkt er harmlos. Doch der Eindruck täuscht. Der Lucid Air Sapphire beschleunigt schneller als ein Formel-1-Bolide und vermittelt ein Fahrgefühl, wie man es bei einem Elektroauto… [+18 chars]'},
#   {'source': {'id': None, 'name': 'Notebookcheck.net'},
#    'author': 'Daniel Zlatev',
#    'title': 'Big Model Y price cut shows how Tesla plans to go around Canada tariffs as delivery times extend to September',
#    'description': 'The Tesla Model Y price has been cut by 25%, after becoming prohibitively expensive to account for reciprocal tariffs in Canada. Tesla has sold off its inventory of pre-tariff vehicles, and has now found a way to get around tariffs.',
#    'url': 'https://www.notebookcheck.net/Big-Model-Y-price-cut-shows-how-Tesla-plans-to-go-around-Canada-tariffs-as-delivery-times-extend-to-September.1056153.0.html',
#    'urlToImage': 'https://www.notebookcheck.net/fileadmin/Notebooks/News/_nc4/model-y-7-seat-1.jpg',
#    'publishedAt': '2025-07-11T09:40:00Z',
#    'content': 'Tesla has dropped the Model Y price by the whopping CA$20,000 up in Canada, bringing it down from CA$84,990, or 62,025 US dollars, to CA$64,990. For comparison, the same Model Y Long Range RWD varian… [+2367 chars]'},
#   {'source': {'id': None, 'name': 'Slate Magazine'},
#    'author': 'Felipe De La Hoz',
#    'title': 'Could Trump Actually Deport Elon Musk? I Have Some Good News and Some Bad News.',
#    'description': 'The Trump-controlled immigration courts have no jurisdiction over U.S. citizens.',
#    'url': 'https://slate.com/news-and-politics/2025/07/can-trump-deport-elon-musk-good-news.html',
#    'urlToImage': 'https://compote.slate.com/images/a193296e-5b0e-45a8-88c9-2684f8275276.jpeg?crop=1560%2C1040%2Cx0%2Cy0&width=1560',
#    'publishedAt': '2025-07-11T09:40:00Z',
#    'content': 'Sign up for the Slatest to get the most insightful analysis, criticism, and advice out there, delivered to your inbox daily.\r\nIn the midst of President Donald Trump and Stephen Millers totalizing imm… [+9751 chars]'},
#   {'source': {'id': None, 'name': 'Meneame.net'},
#    'author': 'Hombre_de_Estado',
#    'title': 'El Grupo Volkswagen acelera y da el ‘sorpasso’ a Tesla en Europa: ya vende más coches eléctricos que nadie',
#    'description': 'Al Grupo Volkswagen le costaba adaptar sus coches (y sobre todo, precios) al gran público. Ahora logra su objetivo inicial: vender más eléctricos que nadie en Europa, como muestran sus resultados de ventas de coches eléctricos en el primer semestre de 2025: 4…',
#    'url': 'https://www.meneame.net/m/actualidad/grupo-volkswagen-acelera-da-sorpasso-tesla-europa-ya-vende-mas',
#    'urlToImage': 'https://www.meneame.net/backend/media?type=link&id=4076538&version=0&ts=1752226566&image.webp',
#    'publishedAt': '2025-07-11T09:30:07Z',
#    'content': ''},
#   {'source': {'id': None, 'name': 'Olhardigital.com.br'},
#    'author': 'Bob Furuya',
#    'title': 'Caminhão da Tesla: produção deve começar no fim do ano',
#    'description': 'Elon Musk falou pela primeira vez sobre o elétrico Semi em 2017; veículo deve ter uma das maiores autonomias do mercado.\nO post Caminhão da Tesla: produção deve começar no fim do ano apareceu primeiro em Olhar Digital.',
#    'url': 'https://olhardigital.com.br/2025/07/11/carros-e-tecnologia/caminhao-da-tesla-producao-deve-comecar-no-fim-do-ano/',
#    'urlToImage': 'https://img.odcdn.com.br/wp-content/uploads/2025/07/Captura-de-tela-2025-07-10-161626.jpg',
#    'publishedAt': '2025-07-11T09:30:00Z',
#    'content': 'O ano era 2017 quando a Tesla apresentou o Semi. O caminhão elétrico da marca chamou rapidamente a atenção do mercado. Tinha uma autonomia fora do comum e foi uma excelente notícia para as grandes co… [+3023 chars]'},
#   {'source': {'id': None, 'name': 'Cossa.ru'},
#    'author': None,
#    'title': 'Лидерство и\xa0инновации: развиваем креативность руководителей в\xa0условиях изменений',
#    'description': 'Почему крупные компании как никогда активно инвестируют в\xa0развитие творческого мышления.',
#    'url': 'https://www.cossa.ru/trends/341951/',
#    'urlToImage': 'http://www.cossa.ru/upload/iblock/7aa/6wvvu8yaoss4729qvf01yyabrpgka0xg/12001.jpg',
#    'publishedAt': '2025-07-11T09:29:00Z',
#    'content': ': , .\r\n\xa0 \xa0 . \xa0 , \xa0 , \xa0 .\r\n\xa0 . SHIVA, \xa0 :\r\n<ul><li>\r\n Split\xa0 \xa0 ;\r\n</li><li>\r\n Horrible\xa0 \xa0 ;\r\n</li><li>\r\n Inconceivable\xa0 \xa0 \xa0 ;\r\n</li><li>\r\n Vicious\xa0 \xa0 ;\r\n</li><li>\r\n Arising\xa0 , \xa0 .\r\n</li></ul> Wildberr… [+875 chars]'},
#   {'source': {'id': None, 'name': 'TechNode'},
#    'author': 'Jill Shen',
#    'title': 'NIO starts pre-sale of three-row Onvo L90 SUV at game-changing $27,000 price',
#    'description': 'The success of NIO’s second model under the Onvo brand is vital to the company’s financial well-being, after the first Onvo car, the L60, failed to meet its delivery targets.',
#    'url': 'http://technode.com/2025/07/11/nio-starts-pre-sale-of-three-row-onvo-l90-suv-at-game-changing-27000-price/',
#    'urlToImage': 'https://technode.com/wp-content/uploads/2025/04/WechatIMG3311.jpg',
#    'publishedAt': '2025-07-11T09:28:40Z',
#    'content': 'Every Wednesday and Friday, TechNodes Briefing newsletter delivers a roundup of the most important news in China tech, straight to your inbox.\r\nNIO said on Thursday its Onvo L90 three-row sports util… [+2898 chars]'},
#   {'source': {'id': None, 'name': 'Frandroid'},
#    'author': 'Marie Lizak',
#    'title': 'Xpeng lance en France la plus grande concurrente de la Tesla Model Y : voici ses prix',
#    'description': 'C’est officiel, les nouveaux Xpeng G6 et G9 restylés débarquent en France avec leur recharge en seulement 12 minutes. Les deux voitures électriques chinoises sont disponibles à la commande et dévoilent enfin leur tarif.',
#    'url': 'https://www.frandroid.com/marques/xpeng/2730851_xpeng-lance-en-france-la-plus-grande-concurrente-de-la-tesla-model-y-voici-ses-prix',
#    'urlToImage': 'https://c0.lestechnophiles.com/images.frandroid.com/wp-content/uploads/2025/06/wip-embargo-by-june12-9amnew-g6g9-recadre.jpg?resize=1600,900&key=1cb85e08&watermark',
#    'publishedAt': '2025-07-11T09:25:46Z',
#    'content': 'C’est officiel, les nouveaux Xpeng G6 et G9 restylés débarquent en France avec leur recharge en seulement 12 minutes. Les deux voitures électriques chinoises sont disponibles à la commande et dévoile… [+4140 chars]'},
#   {'source': {'id': None, 'name': 'Gagadget.com'},
#    'author': 'gagadget.com',
#    'title': 'Grok 4 подозревают в подстраивании под мысли Илона Маска',
#    'description': 'Новейшая модель искусственного интеллекта Grok 4, которую на этой неделе представила компания xAI, привлекла внимание не только благодаря высоким результатам в бенчмарках, но и из-за сомнительного подхода к формированию ответов. Как выяснил TechCrunch, ИИ час…',
#    'url': 'https://gagadget.com/ru/659991-grok-4-podozrevayut-v-podstraivanii-pod-myisli-ilona-maska/',
#    'urlToImage': 'https://gagadget.com/media/cache/a3/aa/a3aa0947faeb7237d6e0cbf15d9a24a5.jpg',
#    'publishedAt': '2025-07-11T09:21:55Z',
#    'content': 'Grok 4, xAI, , - . TechCrunch, Twitter , - .\r\n" " " Twitter"?\r\n Grok 4 , - xAI - ", ". , Grok 4 " " : " ...". TechCrunch - , X, .\r\n " " " "\r\n , Grok " ". xAI " " Grok 4, X "". , .\r\n (OpenAI, Anthropi… [+120 chars]'},
#   {'source': {'id': 'fortune', 'name': 'Fortune'},
#    'author': 'Diane Brady',
#    'title': 'We may never hear Linda Yaccarino’s side of the X story: ‘There’s always a nondisclosure where you can’t set the story straight’',
#    'description': 'Also: All the news and watercooler chat from Fortune.',
#    'url': 'https://fortune.com/2025/07/11/linda-yaccarino-x-elon-musk-nondisclosure/',
#    'urlToImage': 'https://fortune.com/img-assets/wp-content/uploads/2025/07/GettyImages-2192344945-e1752159631401.jpg?resize=1200,600',
#    'publishedAt': '2025-07-11T09:20:40Z',
#    'content': 'Good morning. Its clear that Linda Yaccarino was taking on a tough assignment when she became CEO of Twitter, now known as X, about two years ago. Her boss Elon Musk tweeted about a female CEO coming… [+6736 chars]'},
#   {'source': {'id': None, 'name': 'Numerama'},
#    'author': 'Raphaëlle Baut',
#    'title': 'Grok arrive dans les Tesla : certes, mais pour quoi faire ?',
#    'description': 'Annoncé pour une arrivée « dès la semaine prochaine », Grok, l’IA développée par xAI, doit débarquer dans les Tesla. Une nouveauté pleine de promesses à écouter Elon Musk… vraiment ? Elon Musk a encore frappé. Le 10 juillet, le patron de Tesla a annoncé que G…',
#    'url': 'https://www.numerama.com/vroom/2031909-grok-arrive-dans-les-tesla-certes-mais-pour-quoi-faire.html',
#    'urlToImage': 'https://c0.lestechnophiles.com/www.numerama.com/wp-content/uploads/2023/12/elon-musk-itw.jpg?resize=1600,900&key=b5b3d132&watermark',
#    'publishedAt': '2025-07-11T09:17:37Z',
#    'content': 'Annoncé pour une arrivée « dès la semaine prochaine », Grok, l’IA développée par xAI, doit débarquer dans les Tesla. Une nouveauté pleine de promesses à écouter Elon Musk… vraiment ?\r\nElon Musk a enc… [+5009 chars]'},
#   {'source': {'id': None, 'name': 'Marketingdirecto.com'},
#    'author': 'Esther Lastra',
#    'title': 'Grok, el controvertido chatbot de Elon Musk, parloteará también en los coches de Tesla',
#    'description': 'Grok 4, que se integrará en los coches de Tesla, dispone de habilidades avanzadas de comprensión de texto y es más fluido en las respuestas proporcionadas al usuario. \nLa entrada Grok, el controvertido chatbot de Elon Musk, parloteará también en los coches de…',
#    'url': 'https://www.marketingdirecto.com/digital-general/digital/grok-chatbot-elon-musk-parloteara-coches-tesla',
#    'urlToImage': 'https://www.marketingdirecto.com/wp-content/uploads/2025/07/grok-tesla.webp',
#    'publishedAt': '2025-07-11T09:17:19Z',
#    'content': 'Grok 4, que se integrará en los coches de Tesla, dispone de habilidades avanzadas de comprensión de texto y es más fluido en las respuestas proporcionadas al usuario.Elon Musk presentaba ayer entre g… [+2574 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Lauren Edmonds',
#    'title': 'Here are the biggest companies that have followed Elon Musk out of Delaware',
#    'description': 'Elon Musk urged companies to ditch Delaware last year after a judge voided his $55 billion pay package.',
#    'url': 'https://www.businessinsider.com/list-corporations-leaving-delaware-elon-musk-spacex-tesla-dropbox-roblox-2025-7',
#    'urlToImage': 'https://i.insider.com/68700ef8f748d8c055f56230?width=1200&format=jpeg',
#    'publishedAt': '2025-07-11T09:15:01Z',
#    'content': 'Elon Musk reincorporated SpaceX from Delaware to Texas in 2024, sparking a wider exodus from the historically business-friendly state.Kevin Dietsch/Getty Images\r\n<ul><li>Multiple companies are leavin… [+7997 chars]'},
#   {'source': {'id': None, 'name': 'Hwupgrade.it'},
#    'author': None,
#    'title': 'Tra poco potrai parlare con la tua Tesla, quantomeno secondo Elon Musk',
#    'description': 'Elon Musk ha annunciato su X che Grok, l\x92assistente AI sviluppato da xAI, sarà integrato nei veicoli Tesla \x93molto presto\x94. L\x92annuncio arriva dopo il lancio del nuovo modello Grok 4 e, secondo il CEO, il modello IA arriverà entro la prossima settimana al più t…',
#    'url': 'https://greenmove.hwupgrade.it/news/auto-elettriche/tra-poco-potrai-parlare-con-la-tua-tesla-quantomeno-secondo-elon-musk_140979.html',
#    'urlToImage': 'https://www.hwupgrade.it/i/n/Tesla_FSD_Parigi_720.jpg',
#    'publishedAt': '2025-07-11T09:14:56Z',
#    'content': "L'integrazione di Grok, l'assistente basato su intelligenza artificiale sviluppato da xAI, all'interno dei veicoli Tesla è ormai imminente, quantomeno secondo il CEO dell'azienda. Lo ha annunciato, i… [+2561 chars]"},
#   {'source': {'id': None, 'name': 'Excelsior.com.mx'},
#    'author': 'citlallin.andrade',
#    'title': 'La extraña muerte del ministro de Transportes de Rusia',
#    'description': 'Leía días atrás que se está volviendo una moda en la élite rusa morir de manera extraña: ya sea suicidarse con un balazo en la cabeza o aventarse de un departamento al vacío.\r\n\nPara los políticos y funcionarios cercanos al Kremlin, un balazo en la cabeza. Par…',
#    'url': 'https://www.excelsior.com.mx/opinion/ricardo-ortiz-esquivel/la-extrana-muerte-del-ministro-de-transportes-de-rusia/1726575',
#    'urlToImage': 'https://www.excelsior.com.mx/media/opinion/vertical/2020/10/23/2464635.jpeg',
#    'publishedAt': '2025-07-11T09:12:39Z',
#    'content': 'Leía días atrás que se está volviendo una moda en la élite rusa morir de manera extraña: ya sea suicidarse con un balazo en la cabeza o aventarse de un departamento al vacío.\r\nPara los políticos y fu… [+3271 chars]'},
#   {'source': {'id': None, 'name': 'Faz.net'},
#    'author': 'Harald Staun',
#    'title': 'Elon Musks „America Party“: Die Disruption der Disruption',
#    'description': 'Musks neueste Pläne bringen Trumps System der Systemsprenger ganz schön durcheinander. Steckt auch dahinter ein Masterplan?',
#    'url': 'https://www.faz.net/aktuell/feuilleton/debatten/elon-musks-america-party-disruption-der-disruption-110585914.html',
#    'urlToImage': 'https://media0.faz.net/ppmedia/aktuell/1526858127/1.10585992/facebook_teaser/elon-musk-noch-auf-linie-im.jpg',
#    'publishedAt': '2025-07-11T09:10:23Z',
#    'content': 'Die ideologischen Fronten zwischen den verschiedenen Lagern der Gefolgs\xadleute von Donald Trump zeichneten sich schon seit längerer Zeit ab. Dass irgendwann Risse in der Al\xadlianz von außenpolitischen … [+3486 chars]'},
#   {'source': {'id': None, 'name': 'Mail.ru'},
#    'author': 'Известия - Общий',
#    'title': 'Большинство проданных в России VW и Toyota оказались выпущены в Китае',
#    'description': 'Доля новых китайских Tesla в\xa0России в\xa0этом году составляет 38%',
#    'url': 'https://auto.mail.ru/article/108514-bolshinstvo-prodannyih-v-rossii-vw-i-toyota-okazalis-vyipuschenyi-v-kitae/',
#    'urlToImage': 'https://resizer.mail.ru/p/8594ca2e-8a86-5282-a30b-94efd352ab99/AQABnHCsJn2hX5_bprOHa-aKYFBlslKVTYTbrYwBdSAkasLPHSJpUrETu1K3oVHGa9vLUfpfMWMo63gfvMkQo_mNV14.jpg',
#    'publishedAt': '2025-07-11T09:10:00Z',
#    'content': '37,5 . , \xa0 \xa0, \xa0, \xa0 \xa02025 , 43% (16,1 . .) \xa0. \xa0 \xa0 Telegram- «» .\r\n, \xa0 , \xa0 \xa0 \xa0Volkswagen\xa0— 93%. \xa0 Mazda (83%, \xa0\xa0\xa0— Toyota (75%), \xa0 \xa0 6158 .\r\nSkoda (52%), Honda (46%), Kia (42%), Audi (38%), BMW (30%), … [+52 chars]'},
#   {'source': {'id': None, 'name': '3dnews.ru'},
#    'author': None,
#    'title': 'Xiaomi SU7 меньше всех китайских электрокаров теряет в цене на вторичном рынке',
#    'description': 'Поставки дебютного автомобиля SU7 компания Xiaomi начала в марте прошлого года, и за последующие 15 месяцев успела отгрузить клиентам 300 000 электромобилей. Как уже отмечалось, молодому по меркам отрасли автопроизводителю удалось занять восьмое место в рейти…',
#    'url': 'https://3dnews.ru/1125811/xiaomi-su7-menshe-vseh-kitayskih-elektrokarov-teryaet-v-tsene-na-vtorichnom-rinke',
#    'urlToImage': 'https://3dnews.ru/assets/external/illustrations/2025/07/11/1125811/yu7_01.jpg',
#    'publishedAt': '2025-07-11T09:05:00Z',
#    'content': 'SU7 Xiaomi , 15 300 000 . , . , SU7 .\r\n: Xiaomi\r\nCarNewsChina, Xiaomi 2021 , , 15 . SU7 28 2025 . SU7 Ultra 27 . , YU7 , 6 . 15 .\r\n Xiaomi 300- . , , 464 . 647 , , . 27 . Xiaomi 511 . 160 513 , , 840… [+147 chars]'},
#   {'source': {'id': 'nbc-news', 'name': 'NBC News'},
#    'author': 'Kevin Collier, Bruna Horvath',
#    'title': 'X advertisers remain silent after Grok goes off the rails and CEO resigns',
#    'description': 'Most advertisers on X are choosing to remain silent on their future plans and relationship with the company after Grok went on a racist and antisemitic spree.',
#    'url': 'https://www.nbcnews.com/tech/social-media/grok-4-heavy-x-advertisers-silent-goes-musk-ceo-resigns-elon-linda-rcna217987',
#    'urlToImage': 'https://media-cldnry.s-nbcnews.com/image/upload/t_nbcnews-fp-1200-630,f_auto,q_auto:best/rockcms/2025-07/250703-Musk-aa-251-4c72c7.jpg',
#    'publishedAt': '2025-07-11T09:00:00Z',
#    'content': 'Most major advertisers on X are choosing to remain silent about their plans and relationship with the company after the platforms AI chatbot, Grok, went on a racist and antisemitic posting spree Tues… [+5535 chars]'},
#   {'source': {'id': None, 'name': 'Montevideo.com.uy'},
#    'author': 'Montevideo Portal',
#    'title': 'Grok4: la IA de Elon Musk se estrena con polémica antisemita y promesas hiperbólicas',
#    'description': 'El chatbot de X promete ser “la más inteligente del mundo”, pero enfrenta duras críticas por reproducir discursos de odio',
#    'url': 'https://www.montevideo.com.uy/Ciencia-y-Tecnologia/Grok4-la-IA-de-Elon-Musk-se-estrena-con-polemica-antisemita-y-promesas-hiperbolicas-uc929774',
#    'urlToImage': 'https://imagenes.montevideo.com.uy/imgnoticias/202507/_W933_80/925330.jpg',
#    'publishedAt': '2025-07-11T09:00:00Z',
#    'content': 'La nueva versión del asistente conversacional de Elon Musk, Grok4, se presentó esta semana como el modelo de inteligencia artificial "más avanzado del mundo", según su creador. Sin embargo, su lanzam… [+3232 chars]'},
#   {'source': {'id': None, 'name': 'Idnes.cz'},
#    'author': 'Matěj  Klimša',
#    'title': 'Chátrala a hrozilo jí zřícení. Budova Eliášky má nyní naději na záchranu',
#    'description': 'Zchátralá budova Eliášky, bývalé slavné továrny na výrobu lustrů v Kamenickém Šenově, má šanci na obnovu. Stavba se secesním průčelím od sedmdesátých let chátrá a situaci ještě zhoršil požár z léta roku 2023, kdy budově hrozilo i zřícení. Areál nyní koupil no…',
#    'url': 'https://www.idnes.cz/liberec/zpravy/eliaska-kamenicky-senov-zchatrala-budova-tovarna-vyroba-lustru.A250711_860392_liberec-zpravy_cink',
#    'urlToImage': 'https://1gr.cz/tempimg/fb/2025/7/CIN4fa9c43355_15ten_17_01_Filip_Svacha.jpg',
#    'publishedAt': '2025-07-11T08:57:00Z',
#    'content': 'Zájem o Eliáku, jak se budov pezdívá, dlouhodob projevoval potomek významné vídeské rodiny Lobmeyr Peter Rath, který za úelem záchrany budovy zaloil roce 2000 Evropskou spolenost pro svtlo a sklo Lig… [+2173 chars]'},
#   {'source': {'id': None, 'name': 'DIE WELT'},
#    'author': 'WELT',
#    'title': 'Musk will Skandal-KI Grok in Teslas einbauen',
#    'description': 'Einen Tag nachdem Elon Musks KI-Chatbot Grok mit antisemitischen Äußerungen aufgefallen war, wurde eine neue, leistungsstärkere Version der Software vorgestellt. Grok soll bald auch in Teslas verfügbar sein.',
#    'url': 'https://www.welt.de/vermischtes/article256386384/Musk-will-umstrittenen-KI-Chatbot-Grok-in-Teslas-einbauen.html',
#    'urlToImage': 'https://images.welt.de/6870c49876c936104ca778c4/8a66a8c45fb21b6e93b33e24151a70a0-master/ci16x9-w1200/grok-chatbot',
#    'publishedAt': '2025-07-11T08:50:29Z',
#    'content': 'Tech-Milliardär Elon Musk will seinen KI-Chatbot Grok in Tesla-Autos bringen. Sehr bald. Spätestens nächste Woche, schrieb Musk zum Zeitplan auf seiner Online-Plattform X. Er machte keine Angaben daz… [+1704 chars]'},
#   {'source': {'id': None, 'name': 'Habr.com'},
#    'author': 'Prostomanager',
#    'title': 'Сравнение методологий продуктовой разработки и фреймворков бизнес моделей',
#    'description': 'Как продакты выбирают методологию разработки — и почему это вообще важно? Выбор подхода к разработке определяет дальнешие шаги дя разработки роадмепов, верстке бюджетов и выстраиванию процессов в команде. Это решение, от которого напрямую зависят Time to Mark…',
#    'url': 'https://habr.com/ru/articles/926866/#post-content-body',
#    'urlToImage': 'https://habr.com/share/publication/926866/ce7ec501085cf91a3bcb7230ad587edc/',
#    'publishedAt': '2025-07-11T08:44:16Z',
#    'content': ', , :« ?»CPO . : , , , ? Time to Market , . , . , , . , , , .\r\n :\r\n<ol><li>« / ». : - , . , , .\r\n</li><li>«, ». , , .\r\n</li><li>« , ». , , , , , , .\r\n</li></ol> , ( ) , . -: BMC Lean Canvas Blue Ocea… [+5364 chars]'},
#   {'source': {'id': None, 'name': 'Haberturk.com'},
#    'author': 'Habertürk',
#    'title': 'Tesla marka araç elektrik direğine çarptı!',
#    'description': "Malatya'da korkunç bir kaza meydana geldi. Olayda Tesla marka bir araç aydınlatma direğine çarptıktan sonra alev alarak yanmaya başladı. Feci kazada araçta bulunan Ozan Uçar ile Uğur Oğraş adlı iki hemşire yanarak hayatını kaybetti",
#    'url': 'https://www.haberturk.com/iki-hemsire-yanarak-hayatini-kaybetti-tesla-marka-arac-elektrik-diregine-carpti-3806380',
#    'urlToImage': 'https://im.haberturk.com/l/2025/07/11/ver1752222797/3806380/jpg/1200x628',
#    'publishedAt': '2025-07-11T08:33:23Z',
#    'content': "Malatya'da aydnlatma direine çarparak alev alan otomobildeki 2 kii, yaamn yitirdi.\r\nDHA'nn haberine göre kaza, gece geç saatlerde Elaz Bulvar üzerinde meydana geldi. Ozan Uçar (33) yönetimindeki otom… [+883 chars]"},
#   {'source': {'id': None, 'name': 'Webrazzi.com'},
#    'author': 'İdil Dilber',
#    'title': 'Elon Musk’ın yapay zeka modeli Grok, Tesla araçlarına geliyor',
#    'description': 'Elon Musk’ın yapay zeka girişimi xAI tarafından geliştirilen büyük dil modeli Grok, çok yakında Tesla araçlarında yerini alacak. Musk, açıklamayı X üzerinden yaptı ve entegrasyonun "en geç önümüzdeki hafta" gerçekleşeceğini\xa0duyurdu.\r\nxAI ile Tesla arasında ar…',
#    'url': 'https://webrazzi.com/2025/07/11/yapay-zeka-modeli-grok-tesla-araclarina-geliyor/',
#    'urlToImage': 'https://cdn.webrazzi.com/uploads/2025/01/tesla-384.png',
#    'publishedAt': '2025-07-11T08:30:00Z',
#    'content': 'Elon Muskn yapay zeka giriimi xAI tarafndan gelitirilen büyük dil modeli Grok, çok yaknda Tesla araçlarnda yerini alacak. Musk, açklamay X üzerinden yapt ve entegrasyonun "en geç önümüzdeki hafta" ge… [+1962 chars]'},
#   {'source': {'id': None, 'name': 'Inside.com.tw'},
#    'author': 'Sherlock',
#    'title': '馬斯克：Gork\xa0聊天機器人將在下週登上特斯拉',
#    'description': '特斯拉 CEO 馬斯克昨日在其旗下 AI 公司 xAI 的發表會後，在 X 上表示 Gork 聊天機器人將在下週登上特斯拉車輛。',
#    'url': 'https://www.inside.com.tw/article/38942-musk-says-gork-chatbot-will-arrive-in-tesla-vehicles-next-week',
#    'urlToImage': 'https://bucket-image.inkmaginecms.com/version/social/9dde7c0f-a597-445c-80dd-9a93db8a4006/image/2025/06/71245f83-c063-4a48-9986-77dd3444cbd6.jpg',
#    'publishedAt': '2025-07-11T08:26:59Z',
#    'content': '7\xa0 9\xa0Elon Musk AI\xa0 xAI\xa0LLMGrok 4Tesla Tesla\xa0 Gork TwinBirchUSA\xa0 Sawyer Merritt\xa0 X\xa0\r\nSawyer Merritt\xa0 X\xa0 Gork\xa0 Tesla\xa0Gork\xa0 Tesla\xa0\r\nGrok is coming to Tesla vehicles very soon. Next week at the latest.\r\n… [+216 chars]'},
#   {'source': {'id': None, 'name': 'Presse-citron'},
#    'author': 'Setra',
#    'title': 'Elon Musk va installer son intelligence artificielle Grok sur les Tesla',
#    'description': 'Elon Musk annonce sur X que l’intelligence artificielle Grok, un concurrent de ChatGPT développé par son laboratoire xAI, va débarquer sur les véhicules Tesla. Celui-ci est déjà utilisé par les robots Optimus.',
#    'url': 'https://www.presse-citron.net/elon-musk-va-installer-son-intelligence-artificielle-grok-sur-les-tesla/',
#    'urlToImage': 'https://www.presse-citron.net/app/uploads/2025/05/Tesla-interieur-1600x900.jpg',
#    'publishedAt': '2025-07-11T08:23:46Z',
#    'content': 'Cela fait un bon moment que le réseau social X propose un accès à Grok, le concurrent de ChatGPT développé par le laboratoire dIA xAI dElon Musk. Et, bientôt, cette intelligence artificielle sera aus… [+2400 chars]'},
#   {'source': {'id': None, 'name': 'Ndtvprofit.com'},
#    'author': 'NDTV Profit Desk',
#    'title': 'Tesla To Launch First India Showroom In Mumbai On July 15',
#    'description': 'Tesla will open its first showroom in India on July 15 at Bandra Kurla Complex in Mumbai, marking its entry into the Indian electric vehicle market with $1 million in imports.',
#    'url': 'https://www.ndtvprofit.com/auto/tesla-to-launch-first-india-showroom-in-mumbai-on-july-15',
#    'urlToImage': 'https://media.assettype.com/bloombergquint%2F2025-06-03%2Fhn82lzsl%2FTesla-Model-Y.jpg?rect=0%2C145%2C3871%2C2032&w=1200&auto=format%2Ccompress&ogImage=true',
#    'publishedAt': '2025-07-11T08:22:36Z',
#    'content': 'Tesla will formally enter the Indian market next week by opening its first showroom in Mumbai on July 15, a move that follows years of preparation and regulatory discussions, as the electric vehicle … [+1281 chars]'},
#   {'source': {'id': None, 'name': 'El Financiero'},
#    'author': 'De jefes .',
#    'title': 'Isuzu va por 10 mil camiones hacia el 2030',
#    'description': 'La marca confía en vender 6 mil unidades al cierre de 2025, 500 más que las comercializadas el año pasado.',
#    'url': 'https://www.elfinanciero.com.mx/opinion/de-jefes/2025/07/11/isuzu-va-por-10-mil-camiones-hacia-el-2030/',
#    'urlToImage': 'https://www.elfinanciero.com.mx/resizer/v2/7H7Y6BRT65GIPC2TJ5XNYOO67E.jpg?smart=true&auth=05e2bf848fdaaf225c544711c1579933ded5ef6fb12931ed09760bc02e6df3c0&width=1200&height=630',
#    'publishedAt': '2025-07-11T08:21:22Z',
# ...
#    'url': 'https://biztoc.com/x/aa21ae443616c86b',
#    'urlToImage': 'https://biztoc.com/cdn/aa21ae443616c86b_s.webp',
#    'publishedAt': '2025-07-11T07:39:46Z',
#    'content': '{ window.open(this.href, \'_blank\'); }, 200); return false;"&gt;What impact will Trump\'s 35% Canada tariff have? { window.open(this.href, \'_blank\'); }, 200); return false;"&gt;Why did Nvidia reach a $… [+761 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'bloomberg.com',
#    'title': 'Economy Stalls',
#    'description': '',
#    'url': 'https://biztoc.com/x/ab86cfc0e1280aba',
#    'urlToImage': 'https://biztoc.com/cdn/ab86cfc0e1280aba_s.webp',
#    'publishedAt': '2025-07-11T07:39:46Z',
#    'content': '{ window.open(this.href, \'_blank\'); }, 200); return false;"&gt;What impact will Trump\'s 35% Canada tariff have? { window.open(this.href, \'_blank\'); }, 200); return false;"&gt;Why did Nvidia reach a $… [+715 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'reuters.com',
#    'title': "Trump's copper tariffs won't lift US output, will boost costs",
#    'description': '',
#    'url': 'https://biztoc.com/x/a21331673c00043c',
#    'urlToImage': 'https://biztoc.com/cdn/950/og.png',
#    'publishedAt': '2025-07-11T07:39:43Z',
#    'content': '{ window.open(this.href, \'_blank\'); }, 200); return false;"&gt;What impact will Trump\'s 35% Canada tariff have? { window.open(this.href, \'_blank\'); }, 200); return false;"&gt;Why did Nvidia reach a $… [+758 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'barrons.com',
#    'title': 'Big Tech Needs a Way Out of Its AI Cost Spiral. These 2 Stocks Could Benefit',
#    'description': '',
#    'url': 'https://biztoc.com/x/a146a8e575fc856a',
#    'urlToImage': 'https://biztoc.com/cdn/a146a8e575fc856a_s.webp',
#    'publishedAt': '2025-07-11T07:39:43Z',
#    'content': '{ window.open(this.href, \'_blank\'); }, 200); return false;"&gt;What impact will Trump\'s 35% Canada tariff have? { window.open(this.href, \'_blank\'); }, 200); return false;"&gt;Why did Nvidia reach a $… [+719 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'news.bloomberglaw.com',
#    'title': "Mark Zuckerberg's top AI talent hiring blitz seems to be causing a halo effect as other leading scientists join Meta in the race to build “superintelligent” AI",
#    'description': '',
#    'url': 'https://biztoc.com/x/ef08cdbaa867a5f8',
#    'urlToImage': 'https://biztoc.com/cdn/950/og.png',
#    'publishedAt': '2025-07-11T07:39:41Z',
#    'content': '{ window.open(this.href, \'_blank\'); }, 200); return false;"&gt;What impact will Trump\'s 35% Canada tariff have? { window.open(this.href, \'_blank\'); }, 200); return false;"&gt;Why did Nvidia reach a $… [+767 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'bloomberg.com',
#    'title': 'China, Japan Discuss Speeding Up Beef Export Ban Lift, NHK Says',
#    'description': '',
#    'url': 'https://biztoc.com/x/437cf9b2b293de7b',
#    'urlToImage': 'https://biztoc.com/cdn/437cf9b2b293de7b_s.webp',
#    'publishedAt': '2025-07-11T07:39:40Z',
#    'content': '{ window.open(this.href, \'_blank\'); }, 200); return false;"&gt;What impact will Trump\'s 35% Canada tariff have? { window.open(this.href, \'_blank\'); }, 200); return false;"&gt;Why did Nvidia reach a $… [+759 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'bloomberg.com',
#    'title': 'Myanmar Junta Chief Hails Trump, Likens Coup to 2020 US Election',
#    'description': '',
#    'url': 'https://biztoc.com/x/1f89a554ff59ae93',
#    'urlToImage': 'https://biztoc.com/cdn/1f89a554ff59ae93_s.webp',
#    'publishedAt': '2025-07-11T07:39:39Z',
#    'content': '{ window.open(this.href, \'_blank\'); }, 200); return false;"&gt;What impact will Trump\'s 35% Canada tariff have? { window.open(this.href, \'_blank\'); }, 200); return false;"&gt;Why did Nvidia reach a $… [+761 chars]'},
#   {'source': {'id': None, 'name': 'Haber7.com'},
#    'author': 'Şule Altınel',
#    'title': 'Yeni aldıkları Tesla alev aldı: 2 hemşire yanarak can verdi',
#    'description': "Malatya'da gece saatlerinde meydana gelen kazada Tesla marka bir otomobil alev alarak yandı. Feci kazada araçta bulunan 2 kişi hayatını kaybetti.",
#    'url': 'https://www.haber7.com/guncel/haber/3546242-yeni-aldiklari-tesla-alev-aldi-2-hemsire-yanarak-can-verdi',
#    'urlToImage': 'https://i12.haber7.net//haber/haber7/og_image/2025/28/yeni_aldiklari_tesla_alev_aldi_2_hemsire_yanarak_can_verdi_1752219579_7075.jpg',
#    'publishedAt': '2025-07-11T07:39:00Z',
#    'content': 'Malatya-Elaz kara yolu üzeri Turgut Özal Tp Merkezi mevkiinde gece saat 04.00 sralarnda feci bir kaza meydana geldi. Edinilen bilgilere göre, Ozan Uçar idaresindeki Tesla marka otomobil, yol kenarnda… [+644 chars]'},
#   {'source': {'id': None, 'name': 'Bolsamania.com'},
#    'author': 'redaccion@bolsamania.com (César Nuez)',
#    'title': 'Valores destacados al cierre del mercado norteamericano',
#    'description': 'Subidas del 4,73% en Tesla que intenta cubrir el hueco bajista que se dejara, el pasado lunes en los 315,35 dólares.',
#    'url': 'https://www.bolsamania.com/noticias/analisis-tecnico/valores-destacados-al-cierre-del-mercado-norteamericano--20272960.html',
#    'urlToImage': 'https://img4.s3wfg.com/web/img/images_uploaded/5/8/cbwallstreetsombra.jpg',
#    'publishedAt': '2025-07-11T07:33:54Z',
#    'content': 'Subidas del 4,73% en Tesla que intenta cubrir el hueco bajista que se dejara, el pasado lunes en los 315,35 dólares.\r\nEn estos precios se encuentra la media de 200 sesiones. No veremos una señal de f… [+656 chars]'},
#   {'source': {'id': None, 'name': 'Everyeye.it'},
#    'author': 'Alessio Marino',
#    'title': 'Da dove viene la "verità" di Grok 4? L\'IA è appiattita sulle opinioni di Musk',
#    'description': "Grok 4, l'IA di xAI, riflette spesso le opinioni del suo fondatore su temi sensibili, suscitando nuove polemiche su imparzialità e sicurezza.Sebbene Grok 4 abbia mostrato performance superiori agli altri modelli d’IA, quando viene interrogato su temi controve…",
#    'url': 'https://tech.everyeye.it/notizie/viene-verita-grok-4-ia-appiattita-opinioni-musk-813656.html',
#    'urlToImage': 'https://images.everyeye.it/img-notizie/da-viene-veritA-grok-4-ia-appiattita-opinioni-musk-v3-813656.jpg',
#    'publishedAt': '2025-07-11T07:33:00Z',
#    'content': 'Sebbene Grok 4 abbia mostrato performance superiori agli altri modelli d’IA, quando viene interrogato su temi controversi le sue opinioni sembrano essere appiattite su quelle del suo fondatore, Elon … [+1305 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'reuters.com',
#    'title': "India's BPCL plans to shut Bina refinery unit for 15-day maintenance in August",
#    'description': '',
#    'url': 'https://biztoc.com/x/e8d1f2245f58d112',
#    'urlToImage': 'https://biztoc.com/cdn/e8d1f2245f58d112_s.webp',
#    'publishedAt': '2025-07-11T07:28:47Z',
#    'content': '{ window.open(this.href, \'_blank\'); }, 200); return false;"&gt;What impact will Trump\'s 35% Canada tariff have? { window.open(this.href, \'_blank\'); }, 200); return false;"&gt;Why did Nvidia reach a $… [+767 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'reuters.com',
#    'title': 'European shares dip as Trump widens trade war, EU tariffs in focus',
#    'description': '',
#    'url': 'https://biztoc.com/x/8d66e5f3cf5f1c1e',
#    'urlToImage': 'https://biztoc.com/cdn/8d66e5f3cf5f1c1e_s.webp',
#    'publishedAt': '2025-07-11T07:28:41Z',
#    'content': '{ window.open(this.href, \'_blank\'); }, 200); return false;"&gt;What impact will Trump\'s 35% Canada tariff have? { window.open(this.href, \'_blank\'); }, 200); return false;"&gt;Why did Nvidia reach a $… [+754 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'reuters.com',
#    'title': "Russia's Novatek says Q2 gas output up 2.8% y/y",
#    'description': '',
#    'url': 'https://biztoc.com/x/adde174a7a897614',
#    'urlToImage': 'https://biztoc.com/cdn/adde174a7a897614_s.webp',
#    'publishedAt': '2025-07-11T07:28:40Z',
#    'content': '{ window.open(this.href, \'_blank\'); }, 200); return false;"&gt;What impact will Trump\'s 35% Canada tariff have? { window.open(this.href, \'_blank\'); }, 200); return false;"&gt;Why did Nvidia reach a $… [+739 chars]'},
#   {'source': {'id': None, 'name': 'Mail.ru'},
#    'author': 'Авто Mail',
#    'title': 'Владелец «Теслы» устроил онлайн-розыгрыш',
#    'description': 'Владельцев Tesla опубликовал в Сети состряпанное им самим письмо от автопроизводителя по случаю его дня рождения. К письму якобы прилагался подарок',
#    'url': 'https://auto.mail.ru/article/108505-vladelec-tesly-ustroil-onlajn-rozygrysh/',
#    'urlToImage': 'https://resizer.mail.ru/p/5002862b-3302-539b-8e74-46e56df92f6c/AQABxzTfPO1A27AZwJG7Sp6fymQshwPx04HP959OoZEuGtmwPryDvFrnUPjJp64I-2G9o4JhrPWTbBEUtGo21jo-Gsc.jpg',
#    'publishedAt': '2025-07-11T07:20:10Z',
#    'content': '«» \xa0 , \xa0 . \xa0 , \xa0 : « Tesla \xa050\xa0.., \xa0 30 »'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'investing.com',
#    'title': "Fitch upgrades Bulgaria to 'BBB+' on euro adoption approval",
#    'description': '',
#    'url': 'https://biztoc.com/x/4be3394a5cc0e6d8',
#    'urlToImage': 'https://biztoc.com/cdn/950/og.png',
#    'publishedAt': '2025-07-11T07:17:30Z',
#    'content': '{ window.open(this.href, \'_blank\'); }, 200); return false;"&gt;What impact will Trump\'s 35% Canada tariff have? { window.open(this.href, \'_blank\'); }, 200); return false;"&gt;Why did Nvidia reach a $… [+748 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'bloomberg.com',
#    'title': 'SAP CEO Says Client ‘Transformation’ Will Spur Growth Until 2030',
#    'description': '',
#    'url': 'https://biztoc.com/x/7ea5b843850c7ef3',
#    'urlToImage': 'https://biztoc.com/cdn/7ea5b843850c7ef3_s.webp',
#    'publishedAt': '2025-07-11T07:17:17Z',
#    'content': '{ window.open(this.href, \'_blank\'); }, 200); return false;"&gt;What impact will Trump\'s 35% Canada tariff have? { window.open(this.href, \'_blank\'); }, 200); return false;"&gt;Why did Nvidia reach a $… [+760 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'bloomberg.com',
#    'title': 'India Weighs First New Bank Licenses in a Decade to Fund Growth',
#    'description': '',
#    'url': 'https://biztoc.com/x/33e4756a3aaad2c5',
#    'urlToImage': 'https://biztoc.com/cdn/33e4756a3aaad2c5_s.webp',
#    'publishedAt': '2025-07-11T07:17:13Z',
#    'content': '{ window.open(this.href, \'_blank\'); }, 200); return false;"&gt;What impact will Trump\'s 35% Canada tariff have? { window.open(this.href, \'_blank\'); }, 200); return false;"&gt;Why did Nvidia reach a $… [+761 chars]'},
#   {'source': {'id': None, 'name': '3dnews.ru'},
#    'author': None,
#    'title': 'Проблемы Tesla и электромобильного рынка США в целом вынудили Panasonic притормозить строительство аккумуляторного завода в США',
#    'description': 'На волне электромобильного энтузиазма, активно подогреваемого правительством бывшего президента США Джозефа Байдена (Joseph Biden), японская корпорация Panasonic решилась на строительство второго предприятия на территории США, которое расположилось в Канзасе.…',
#    'url': 'https://3dnews.ru/1125802/problemi-tesla-i-elektromobilnogo-rinka-ssha-v-tselom-vinudili-panasonic-pritormozit-stroitelstvo-akkumulyatornogo-zavoda-v-ssha',
#    'urlToImage': 'https://3dnews.ru/assets/external/illustrations/2025/07/11/1125802/panasonic_01.jpg',
#    'publishedAt': '2025-07-11T07:15:00Z',
#    'content': ', (Joseph Biden), Panasonic , . , .\r\n: Panasonic\r\n, Nikkei Asian Review, Panasonic 2027 , , 30 . , Panasonic , . , , Tesla.\r\n Panasonic $4 . , . Tesla Panasonic , . , Panasonic , . 2030 $20,4 . Panas… [+14 chars]'},
#   {'source': {'id': None, 'name': 'ETF Daily News'},
#    'author': 'MarketBeat News',
#    'title': 'Automotive Stocks To Watch Today – July 8th',
#    'description': 'Tesla, NVIDIA, Bank of America, Micron Technology, SoundHound AI, Taiwan Semiconductor Manufacturing, and Salesforce are the seven Automotive stocks to watch today, according to MarketBeat’s stock screener tool. Automotive stocks are shares of publicly traded…',
#    'url': 'https://www.etfdailynews.com/2025/07/11/automotive-stocks-to-watch-today-july-8th/',
#    'urlToImage': 'https://www.americanbankingnews.com/wp-content/timthumb/timthumb.php?src=https://www.marketbeat.com/logos/tesla-inc-logo-1200x675.png?v=20221020135629&w=240&h=240&zc=2',
#    'publishedAt': '2025-07-11T07:14:52Z',
#    'content': 'Tesla, NVIDIA, Bank of America, Micron Technology, SoundHound AI, Taiwan Semiconductor Manufacturing, and Salesforce are the seven Automotive stocks to watch today, according to MarketBeat’s stock sc… [+8897 chars]'},
#   {'source': {'id': None, 'name': 'ETF Daily News'},
#    'author': 'MarketBeat News',
#    'title': 'Best Insurance Stocks To Follow Today – July 9th',
#    'description': 'Tesla, UnitedHealth Group, and SoFi Technologies are the three Insurance stocks to watch today, according to MarketBeat’s stock screener tool. Insurance stocks are shares of publicly traded companies whose primary business is providing insurance products, suc…',
#    'url': 'https://www.etfdailynews.com/2025/07/11/best-insurance-stocks-to-follow-today-july-9th/',
#    'urlToImage': 'https://www.americanbankingnews.com/wp-content/timthumb/timthumb.php?src=https://www.marketbeat.com/logos/tesla-inc-logo-1200x675.png?v=20221020135629&w=240&h=240&zc=2',
#    'publishedAt': '2025-07-11T07:14:51Z',
#    'content': 'Tesla, UnitedHealth Group, and SoFi Technologies are the three Insurance stocks to watch today, according to MarketBeat’s stock screener tool. Insurance stocks are shares of publicly traded companies… [+4106 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'bloomberg.com',
#    'title': 'BYD, Chery Among Carmakers Found to Have Claimed Extra Subsidies',
#    'description': '',
#    'url': 'https://biztoc.com/x/376c4b11c0a047a4',
#    'urlToImage': 'https://biztoc.com/cdn/376c4b11c0a047a4_s.webp',
#    'publishedAt': '2025-07-11T07:06:21Z',
#    'content': '{ window.open(this.href, \'_blank\'); }, 200); return false;"&gt;What impact will Trump\'s 35% Canada tariff have? { window.open(this.href, \'_blank\'); }, 200); return false;"&gt;Why did Nvidia reach a $… [+761 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'investing.com',
#    'title': 'Asian stocks attract foreign inflows for second month, but tariff outlook clouds',
#    'description': '',
#    'url': 'https://biztoc.com/x/863c6a7988d37f38',
#    'urlToImage': 'https://biztoc.com/cdn/863c6a7988d37f38_s.webp',
#    'publishedAt': '2025-07-11T07:06:16Z',
#    'content': '{ window.open(this.href, \'_blank\'); }, 200); return false;"&gt;What impact will Trump\'s 35% Canada tariff have? { window.open(this.href, \'_blank\'); }, 200); return false;"&gt;Why did Nvidia reach a $… [+771 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'reuters.com',
#    'title': "Nvidia's market value tops $4 trillion",
#    'description': '',
#    'url': 'https://biztoc.com/x/cef058154c488a42',
#    'urlToImage': 'https://biztoc.com/cdn/950/og.png',
#    'publishedAt': '2025-07-11T07:06:10Z',
#    'content': '{ window.open(this.href, \'_blank\'); }, 200); return false;"&gt;What impact will Trump\'s 35% Canada tariff have? { window.open(this.href, \'_blank\'); }, 200); return false;"&gt;Why did Nvidia reach a $… [+738 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'barrons.com',
#    'title': 'Investing in Private Infrastructure Is Suddenly Hot. Here’s Why',
#    'description': '',
#    'url': 'https://biztoc.com/x/481fc9f1b882f75e',
#    'urlToImage': 'https://biztoc.com/cdn/481fc9f1b882f75e_s.webp',
#    'publishedAt': '2025-07-11T07:06:08Z',
#    'content': '{ window.open(this.href, \'_blank\'); }, 200); return false;"&gt;What impact will Trump\'s 35% Canada tariff have? { window.open(this.href, \'_blank\'); }, 200); return false;"&gt;Why did Nvidia reach a $… [+722 chars]'}]}

# %%
# Target
# Total number of articles
# Author
# Title
# Published At

# %%
total_articles = len(news_data['articles'])
total_articles
# Out:
# 98

# %%
first_article = news_data['articles'][0]
first_article
# Out:
# {'source': {'id': None, 'name': 'Inside the Magic'},
#  'author': 'Chloe James',
#  'title': 'REPORT: Universal Working With Elon Musk To Connect Its Parks Via Tunnels',
#  'description': 'In one of the wildest reports to emerge about Orlando’s theme park industry in recent memory, it seems like Universal wants to work with Elon Musk to build a series of tunnels to connect its sprawling campus. Universal Orlando Resort offers an immersive theme…',
#  'url': 'https://insidethemagic.net/?p=780974&preview=true&preview_id=780974',
#  'urlToImage': 'https://insidethemagic.net/wp-content/uploads/2025/05/epic-universe-2.jpg',
#  'publishedAt': '2025-07-11T10:56:06Z',
#  'content': 'In one of the wildest reports to emerge about Orlando’s theme park industry in recent memory, it seems like Universal wants to work with Elon Musk to build a series of tunnels to connect its sprawlin… [+4036 chars]'}

# %%
news_data['articles'][0].keys()
# Out:
# dict_keys(['source', 'author', 'title', 'description', 'url', 'urlToImage', 'publishedAt', 'content'])

# %%
author = first_article['author']
author
# Out:
# 'Chloe James'

# %%
title=first_article['title']
title
# Out:
# 'REPORT: Universal Working With Elon Musk To Connect Its Parks Via Tunnels'

# %%
publishedAt = first_article['publishedAt']
publishedAt
# Out:
# '2025-07-11T10:56:06Z'

# %%
#Return JSON Format

output_data={"Total Article Counts":total_articles,
             "Title":title,
             "Author":author,
             "Published Date":publishedAt}

output_data
# Out:
# {'Total Article Counts': 98,
#  'Title': 'REPORT: Universal Working With Elon Musk To Connect Its Parks Via Tunnels',
#  'Author': 'Chloe James',
#  'Published Date': '2025-07-11T10:56:06Z'}
